# %%
from pathlib import Path

dataset_root = Path("/kaggle/input/wildlife-aerial-images-from-drone")

yaml_text = f"""
path: {dataset_root}
train: images/train
val: images/valid
test: images/test

# Đọc classes.txt và tự sinh tên lớp
names:
"""

classes = (dataset_root / "classes.txt").read_text().strip().splitlines()
yaml_text += "\n".join([f"  {i}: {c}" for i, c in enumerate(classes)])

Path("waid.yaml").write_text(yaml_text)
print("✅ waid.yaml created:\n", yaml_text)
# Out:
# ✅ waid.yaml created:
#
# path: /kaggle/input/wildlife-aerial-images-from-drone
# train: images/train
# val: images/valid
# test: images/test
#
# # Đọc classes.txt và tự sinh tên lớp
# names:
#   0: sheep
#   1: cattle
#   2: seal
#   3: camelus
#   4: kiang
#   5: zebra

# %%
# !pip install ultralytics --no-deps

from ultralytics import YOLO
import os, subprocess, re
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.228-py3-none-any.whl.metadata (37 kB)
# Downloading ultralytics-8.3.228-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.9 MB/s eta 0:00:00
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.3.228
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import cv2, glob, os, numpy as np, pathlib

def is_bad_image(p):
    try:
        with open(p, "rb") as f:
            data = f.read()
        if not data:
            return "zero-byte"
        arr = np.frombuffer(data, np.uint8)
        im  = cv2.imdecode(arr, cv2.IMREAD_COLOR)
        if im is None:
            return "decode-fail"
        return ""
    except Exception as e:
        return f"exception:{e}"

root = pathlib.Path(".")  # hoặc đặt = dataset_root nếu cần
splits = ["train","valid","test"]
bad = []
for sp in splits:
    for p in glob.glob(f"images/{sp}/**/*", recursive=True):
        if os.path.isdir(p): 
            continue
        ext = os.path.splitext(p)[1].lower()
        if ext not in [".jpg",".jpeg",".png",".bmp",".tif",".tiff",".webp"]:
            continue
        reason = is_bad_image(p)
        if reason:
            bad.append((p, reason))

print("Bad images:", len(bad))
for p, r in bad[:50]:
    print(" -", r, "->", p)
# Out:
# Bad images: 0

# %%
import os, glob, pathlib
miss_img, miss_lbl = [], []
for sp in ["train","valid","test"]:
    imgs = {pathlib.Path(p).stem for p in glob.glob(f"images/{sp}/*.*")}
    lbls = {pathlib.Path(p).stem for p in glob.glob(f"labels/{sp}/*.txt")}
    miss_img += [f"{sp}:{x}" for x in sorted(lbls - imgs)]
    miss_lbl += [f"{sp}:{x}" for x in sorted(imgs - lbls)]
print("Labels trỏ không có ảnh:", len(miss_img))
print(miss_img[:30])
print("Ảnh không có nhãn:", len(miss_lbl))
print(miss_lbl[:30])
# Out:
# Labels trỏ không có ảnh: 0
# []
# Ảnh không có nhãn: 0
# []

# %%
import cv2, numpy as np
from ultralytics.utils import patches

def safe_imread(path, flags=cv2.IMREAD_COLOR):
    with open(path, "rb") as f:
        b = f.read()
    arr = np.frombuffer(b, np.uint8)     # 👈 chuyển bytes -> np.uint8
    img = cv2.imdecode(arr, flags)
    return img

patches.imread = safe_imread
print("✅ Patched ultralytics.utils.patches.imread")
# Out:
# ✅ Patched ultralytics.utils.patches.imread

# %%
# !nvidia-smi

import torch, platform
print("cuda_available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("device_name:", torch.cuda.get_device_name(0))
print("torch:", torch.__version__, "| python:", platform.python_version())
# Out:
# Sat Nov 15 11:16:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# cuda_available: True
# device_name: Tesla T4
# torch: 2.6.0+cu124 | python: 3.11.13

# %%
import numpy as np, cv2, sys
print("numpy module? ", type(np))
print("numpy file    ", getattr(np, "__file__", None))
print("cv2 version   ", cv2.__version__)

path = "/kaggle/input/wildlife-aerial-images-from-drone/images/test/0cba95f9-b89e-4034-8543-86276b057dae_jpg.rf.c8e47f70d213aae466cf3a59fcfd6c0b.jpg"
img = cv2.imread(path)
print("imread is None?", img is None)
print("type(img)      ", type(img))

# so sánh với numpy “sạch”
import importlib
_np = importlib.import_module("numpy")
print("is ndarray?    ", isinstance(img, _np.ndarray))
# Out:
# numpy module?  <class 'module'>
# numpy file     /usr/local/lib/python3.11/dist-packages/numpy/__init__.py
# cv2 version    4.12.0
# imread is None? False
# type(img)       <class 'numpy.ndarray'>
# is ndarray?     True

# %%
from ultralytics import YOLO
import os, sys

# 🧠 load model
model = YOLO("yolo11s.pt")  # hoặc model_ckpt

# 🚀 train
results = model.train(
    data="waid.yaml",      # nhớ trỏ path về /kaggle/working/... để ghi cache
    imgsz=640,
    batch=0.9,               # hoặc -1 (auto ~60% VRAM) theo docs
    nbs=64,                # nominal batch size để tích luỹ/chuẩn hoá
    amp=True,              # nếu từng lỗi AMP -> False
    cache="disk",          # tránh /kaggle/input (read-only)
    workers=2,
    device=0,
    plots=False,
    save_period=-1,
    patience=30,
    epochs = 120
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 143.9MB/s 0.1s
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=0.9, bgr=0.0, box=7.5, cache=disk, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=waid.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=120, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    821730  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,430,114 parameters, 9,430,098 gradients
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 62.9MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.9±0.5 ms, read: 13.4±3.7 MB/s, size: 123.1 KB)
# train: Scanning /kaggle/input/wildlife-aerial-images-from-drone/labels/train... 10056 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10056/10056 139.1it/s 1:12
# WARNING ⚠️ train: Cache directory /kaggle/input/wildlife-aerial-images-from-drone/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 90.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (Tesla T4) 14.74G total, 0.14G reserved, 0.11G allocated, 14.49G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      9430114           0         0.698         339.9         767.8        (1, 3, 640, 640)                    list
#      9430114           0         1.101           179           242        (2, 3, 640, 640)                    list
#      9430114           0         1.674         169.9         203.2        (4, 3, 640, 640)                    list
#      9430114           0         2.907         181.9         223.6        (8, 3, 640, 640)                    list
#      9430114           0         5.509         179.3         252.5       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 39 for CUDA:0 13.05G/14.74G (89%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 118.3±39.7 MB/s, size: 151.5 KB)
# train: Scanning /kaggle/input/wildlife-aerial-images-from-drone/labels/train... 10056 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10056/10056 517.4it/s 19.4s
# WARNING ⚠️ train: Cache directory /kaggle/input/wildlife-aerial-images-from-drone/labels is not writable, cache not saved.
# WARNING ⚠️ train: Skipping caching images to disk, directory not writable
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.3±1.7 ms, read: 9.1±8.9 MB/s, size: 68.0 KB)
# val: Scanning /kaggle/input/wildlife-aerial-images-from-drone/labels/valid... 2873 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2873/2873 150.1it/s 19.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/wildlife-aerial-images-from-drone/labels is not writable, cache not saved.
# WARNING ⚠️ val: Skipping caching images to disk, directory not writable
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.000609375), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/train
# Starting training for 120 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/120      11.6G      1.638      1.302       1.17        641        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.3it/s 27.6s
#                    all       2873      46703      0.817      0.727      0.809      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/120      11.4G      1.494     0.7787      1.063        559        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.9s
#                    all       2873      46703       0.81      0.743      0.823      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/120      11.6G      1.517     0.7906      1.072        624        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 26.1s
#                    all       2873      46703       0.81      0.736      0.793      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/120      12.7G       1.51     0.7826      1.073        582        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 26.4s
#                    all       2873      46703      0.828      0.749      0.823      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/120      14.3G      1.485     0.7506      1.065        903        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.9s
#                    all       2873      46703      0.866      0.784      0.855      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/120      13.7G      1.451     0.7207      1.055        851        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.847      0.806      0.867      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/120      13.1G      1.441     0.7038       1.05        646        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.842      0.754      0.828      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/120      13.6G      1.421     0.6893      1.043        534        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.891      0.836      0.903      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/120      13.5G      1.403     0.6763       1.04        698        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.885      0.844      0.904      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/120      12.9G      1.392      0.662      1.035        874        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.896      0.844      0.902      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/120      13.2G      1.394     0.6597      1.033        785        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.902      0.848       0.92       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/120      12.6G      1.379     0.6549      1.031        810        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.899      0.851      0.912      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/120      12.8G      1.371     0.6414      1.028        808        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.7s
#                    all       2873      46703      0.892      0.835      0.897      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/120        13G      1.362     0.6351      1.024        773        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.919      0.874      0.931      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/120      13.1G      1.352     0.6275      1.019        601        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.919      0.881      0.936      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/120        13G      1.347     0.6241      1.018        826        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.8s
#                    all       2873      46703      0.913      0.877       0.93      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/120      12.8G      1.342     0.6196      1.018        622        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.916      0.874      0.932      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/120      12.2G      1.336     0.6116      1.013        744        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.922      0.873      0.934      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/120      12.6G      1.331     0.6106      1.013        972        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.924      0.889       0.94      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/120      13.6G      1.326     0.6039      1.011        904        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.3s
#                    all       2873      46703      0.923      0.889      0.937      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/120      12.8G      1.325     0.6031      1.012        520        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.928      0.892      0.946      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/120      14.3G       1.31     0.5972      1.008        822        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.931      0.902      0.949      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/120      13.5G      1.308     0.5934      1.007        828        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.7s
#                    all       2873      46703      0.936      0.898      0.949      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/120      11.8G      1.313     0.5948      1.007        688        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703       0.93      0.903      0.948       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/120      14.5G      1.307     0.5894      1.005        826        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.927      0.903      0.948      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/120      12.3G      1.304     0.5857      1.006        701        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.938      0.896      0.949      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/120      13.5G        1.3     0.5845      1.005        549        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.3s
#                    all       2873      46703      0.936      0.905      0.951      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/120      12.8G      1.301     0.5847      1.005        736        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703       0.94      0.899       0.95      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/120      13.3G      1.298     0.5812      1.004        614        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.931      0.898      0.948      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/120      13.9G      1.291     0.5757     0.9995        479        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.931      0.907      0.951      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/120      13.7G      1.292     0.5769          1        706        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.936       0.91      0.954      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/120      13.4G      1.283     0.5706     0.9983        619        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.939      0.907      0.955        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/120      14.1G      1.282     0.5725     0.9972       1020        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.941      0.911      0.954      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/120      12.4G      1.276      0.569      0.996        682        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.938      0.907      0.955      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/120      11.1G      1.273      0.567     0.9951        685        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.7s
#                    all       2873      46703      0.937       0.91      0.957      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/120      10.9G      1.278     0.5653     0.9977        784        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703       0.94      0.914      0.956      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/120        14G      1.266      0.561     0.9907        642        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.939      0.909      0.957      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/120      11.3G      1.271     0.5621     0.9921        616        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.946      0.916      0.961      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/120      13.5G      1.265     0.5588     0.9899        748        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.944      0.919      0.961      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/120        14G      1.263     0.5564     0.9906        858        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.945      0.922      0.963      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/120      14.5G      1.261     0.5552     0.9895        948        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.941      0.917      0.959      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/120        12G      1.265     0.5556     0.9898        747        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.944      0.922      0.963      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/120      12.8G      1.257     0.5515     0.9884        703        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.3s
#                    all       2873      46703       0.94      0.925       0.96      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/120      12.3G      1.256     0.5514     0.9888        764        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.944      0.923      0.962      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/120      12.9G      1.258     0.5504     0.9905        862        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.942      0.924      0.963      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/120      14.4G      1.255     0.5488     0.9898        893        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.943      0.929      0.964      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/120      12.2G       1.24     0.5443     0.9858        740        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.946      0.922      0.963      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/120      11.8G      1.245     0.5429     0.9861       1174        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.947      0.924      0.966      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/120      13.8G      1.242      0.542      0.984        532        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.949      0.923      0.965      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/120      13.4G      1.241     0.5407     0.9853        841        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.944      0.928      0.965      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/120      11.9G      1.242     0.5395      0.986        819        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.949      0.927      0.967      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/120      13.2G      1.235     0.5369     0.9817        578        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.948       0.93      0.967      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/120        13G      1.237     0.5374     0.9836        832        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0.948      0.931      0.968      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/120        13G      1.235     0.5362     0.9826        919        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.5s
#                    all       2873      46703      0.951      0.928      0.968      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/120      12.7G      1.227     0.5346     0.9797        722        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 3:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.4s
#                    all       2873      46703      0
58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.958      0.942      0.974      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     117/120      11.3G      1.057     0.4299     0.9445        342        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 2:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 25.3s
#                    all       2873      46703      0.958      0.942      0.974      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     118/120        12G      1.053     0.4288      0.942        566        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 2:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.5s
#                    all       2873      46703      0.958      0.942      0.973      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     119/120      11.4G       1.05     0.4274     0.9434        446        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 2:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.959      0.942      0.973      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     120/120      11.3G      1.048      0.426     0.9409        662        640: 100% ━━━━━━━━━━━━ 258/258 1.4it/s 2:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4it/s 25.6s
#                    all       2873      46703      0.959      0.941      0.973      0.645
#
# 120 epochs completed in 6.948 hours.
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.228 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,415,122 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2873      46703      0.956      0.943      0.974      0.645
#                  sheep        830      26063      0.974      0.973      0.985      0.671
#                 cattle        932      12605      0.973      0.956      0.982      0.685
#                   seal        701       4926       0.96      0.975      0.987      0.727
#                camelus        154       1271      0.938      0.916      0.963      0.575
#                  kiang        134        837      0.944      0.906      0.962      0.564
#                  zebra        122       1001      0.945      0.932      0.965      0.651
# Speed: 0.2ms preprocess, 5.2ms inference, 0.0ms loss, 0.8ms postprocess per image

# %%
import pandas as pd
from pathlib import Path

# Đường dẫn thư mục run YOLO – chỉnh lại cho đúng
RUN_DIR = Path("runs/detect/train")  # vd: runs/detect/train, hoặc runs/detect/exp120
RESULTS_CSV = RUN_DIR / "results.csv"

df = pd.read_csv(RESULTS_CSV)
print(df.head())
print(df.columns)
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   212.693         1.63801         1.30157         1.16988
# 1      2   426.311         1.49353         0.77875         1.06311
# 2      3   636.756         1.51744         0.79058         1.07210
# 3      4   846.279         1.50950         0.78264         1.07329
# 4      5  1055.390         1.48467         0.75056         1.06506
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.81681            0.72687           0.80926
# 1               0.80951            0.74328           0.82264
# 2               0.80989            0.73590           0.79341
# 3               0.82801            0.74881           0.82312
# 4               0.86624            0.78407           0.85535
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.45778       1.43657       0.72848       1.08856  0.003320
# 1              0.45763       1.48193       0.79290       1.12252  0.006599
# 2              0.45321       1.43158       0.79376       1.09034  0.009822
# 3              0.45773       1.44340       0.86512       1.10671  0.009753
# 4              0.48065       1.42334       0.70784       1.09587  0.009670
#
#      lr/pg1    lr/pg2
# 0  0.003320  0.003320
# 1  0.006599  0.006599
# 2  0.009822  0.009822
# 3  0.009753  0.009753
# 4  0.009670  0.009670
# Index(['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

epochs = df["epoch"]

plt.figure()
# Box loss
plt.plot(epochs, df["train/box_loss"], label="train/box_loss")
if "val/box_loss" in df.columns:
    plt.plot(epochs, df["val/box_loss"], label="val/box_loss")

# Class loss (nếu có)
if "train/cls_loss" in df.columns:
    plt.plot(epochs, df["train/cls_loss"], label="train/cls_loss")
if "val/cls_loss" in df.columns:
    plt.plot(epochs, df["val/cls_loss"], label="val/cls_loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Learning curve – Loss theo epoch (120 epochs)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure()

if "metrics/mAP50(B)" in df.columns:
    plt.plot(epochs, df["metrics/mAP50(B)"], label="mAP50(B)")

if "metrics/mAP50-95(B)" in df.columns:
    plt.plot(epochs, df["metrics/mAP50-95(B)"], label="mAP50-95(B)")

plt.xlabel("Epoch")
plt.ylabel("mAP")
plt.title("mAP theo epoch (120 epochs)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
if "metrics/mAP50(B)" in df.columns:
    best_idx = df["metrics/mAP50(B)"].idxmax()
    best_epoch = int(df.loc[best_idx, "epoch"])
    best_map50 = float(df.loc[best_idx, "metrics/mAP50(B)"])

    print(f"Best mAP50 = {best_map50:.4f} tại epoch {best_epoch}")

    plt.figure()
    plt.plot(epochs, df["metrics/mAP50(B)"], label="mAP50(B)")
    plt.axvline(best_epoch, linestyle="--", label=f"Best epoch = {best_epoch}")
    plt.xlabel("Epoch")
    plt.ylabel("mAP50")
    plt.title("mAP50 theo epoch và epoch tốt nhất")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Best mAP50 = 0.9739 tại epoch 108

# %%
plt.figure()

if "metrics/precision(B)" in df.columns:
    plt.plot(epochs, df["metrics/precision(B)"], label="precision")

if "metrics/recall(B)" in df.columns:
    plt.plot(epochs, df["metrics/recall(B)"], label="recall")

plt.xlabel("Epoch")
plt.ylabel("Giá trị")
plt.title("Precision & Recall theo epoch (120 epochs)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Chọn epoch có mAP50(B) cao nhất
best_idx = df["metrics/mAP50(B)"].idxmax()
best_row = df.loc[best_idx]

best_row
# Out:
# epoch                     108.000000
# time                    22539.800000
# train/box_loss              1.114360
# train/cls_loss              0.465830
# train/dfl_loss              0.945520
# metrics/precision(B)        0.955430
# metrics/recall(B)           0.943090
# metrics/mAP50(B)            0.973940
# metrics/mAP50-95(B)         0.645750
# val/box_loss                1.197260
# val/cls_loss                0.444880
# val/dfl_loss                1.008830
# lr/pg0                      0.001172
# lr/pg1                      0.001172
# lr/pg2                      0.001172
# Name: 107, dtype: float64

# %%
metrics = {}
metrics["mAP50"] = best_row["metrics/mAP50(B)"]
if "metrics/mAP50-95(B)" in df.columns:
    metrics["mAP50-95"] = best_row["metrics/mAP50-95(B)"]
if "metrics/precision(B)" in df.columns:
    metrics["precision"] = best_row["metrics/precision(B)"]
if "metrics/recall(B)" in df.columns:
    metrics["recall"] = best_row["metrics/recall(B)"]

plt.figure()
plt.bar(metrics.keys(), metrics.values())
plt.ylim(0, 1.0)
plt.ylabel("Giá trị")
plt.title(f"Metric tại epoch tốt nhất (epoch = {int(best_row['epoch'])})")
plt.grid(axis="y")
plt.tight_layout()
plt.show()

for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# mAP50: 0.9739
# mAP50-95: 0.6458
# precision: 0.9554
# recall: 0.9431
